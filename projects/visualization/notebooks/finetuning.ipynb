# %%
import sys

sys.path.append("private/home/vivc/code/memory-theory/visualization")

from visualization import visualization_backend

plot_config = {
    "grid_size": [1, 2],
    "plots": [
        # {"type": "show_emb", "position": [0]},
        # {"type": "show_norm_emb", "position": [1]},
        # {"type": "show_level_line", "position": [2]},
        {"type": "show_loss", "position": [0]},
        {"type": "show_level_line", "position": [1]},
    ],
}

# frame creation
for unique_id in [
    "fc269f147f7349de84013c2251e26a15",
]:
    for frame in [0, 1000]:
        visualization_backend(
            unique_id=unique_id,
            start_frame=frame,
            save_ext="finetune/seed",
            plot_config=plot_config,
            file_format="pdf",
        )
